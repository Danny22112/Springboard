# %% [markdown]
# introduction

# %% [markdown]
# import data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

from library.sb_utils import save_file

# %%
# !pip install pillow matplotlib

# %%
from PIL import Image

# %%
image_folder = r"C:\Users\dshaw\Springboard\Pistachio_Image_Dataset\Pistachio_Image_Dataset\Kirmizi_Pistachio"

# %%
image_files = [f for f in os.listdir(image_folder) if f.endswith('.jpg')]

# %%
plt.figure(figsize=(10, 10))

# %%
for i, image_file in enumerate(image_files):
    # Load the image
    image_path = os.path.join(image_folder, image_file)
    image = Image.open(image_path)
    
    # Display the image
    #plt.subplot(3, 3, i+1)  # Adjust the number of rows and columns as needed
    plt.imshow(image)
    plt.axis('off')  # Hide axes
    plt.title(image_file)  # Display the filename as the title

# Show all the images in a grid
plt.tight_layout()
plt.show()

# %%
from PIL import Image

# Correct file path (using raw string)
image_path = r"C:\Users\dshaw\Springboard\Pistachio_Image_Dataset\Pistachio_Image_Dataset\image.jpg"

# Open the image using Pillow
image = Image.open(image_path)
image.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 7
#       4 image_path = r"C:\Users\dshaw\Springboard\Pistachio_Image_Dataset\Pistachio_Image_Dataset\image.jpg"
#       6 # Open the image using Pillow
# ----> 7 image = Image.open(image_path)
#       8 image.show()
#
# File ~\Downloads\Ana\Lib\site-packages\PIL\Image.py:3218, in open(fp, mode, formats)
#    3215     filename = fp
#    3217 if filename:
# -> 3218     fp = builtins.open(filename, "rb")
#    3219     exclusive_fp = True
#    3221 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\dshaw\\Springboard\\Pistachio_Image_Dataset\\Pistachio_Image_Dataset\\image.jpg'

# %%
data = pd.read_jpg(C:\Users\dshaw\Springboard\Pistachio_Image_Dataset\Pistachio_Image_Dataset)
# Out:
#   Cell In[2], line 1
#     data = pd.read_jpg(C:\Users\dshaw\Springboard\Pistachio_Image_Dataset\Pistachio_Image_Dataset)
#                         ^
# SyntaxError: invalid syntax

# %%
# !dir
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 628C-FD9A
#
#  Directory of C:\Users\dshaw\Springboard\Pistachio_Image_Dataset
#
# 12/19/2024  01:16 PM    <DIR>          .
# 12/18/2024  11:58 AM    <DIR>          ..
# 12/18/2024  12:02 PM    <DIR>          .ipynb_checkpoints
# 12/19/2024  10:37 AM    <DIR>          library
# 12/18/2024  11:58 AM    <DIR>          Pistachio_16_Features_Dataset
# 12/18/2024  11:58 AM    <DIR>          Pistachio_28_Features_Dataset
# 12/18/2024  11:58 AM    <DIR>          Pistachio_Image_Dataset
# 12/18/2024  11:58 AM             5,108 Pistachio_Image_Dataset_Request.txt
# 12/19/2024  01:16 PM             4,828 Untitled.ipynb
#                2 File(s)          9,936 bytes
#                7 Dir(s)  180,271,468,544 bytes free
